# %% [markdown]
# ### **Step 1: Import Required Libraries**

# %%
# importing libraries

import pandas as pd
import pymysql
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# %% [markdown]
# ### **Step 2: Load the Dataset**

# %%
# Load the scraped Yelp dataset
df = pd.read_csv("data/yelp_cross_industry_data.csv")
df.head()
# Out:
#         State Business Type                                 Name  Rating  \
# 0  California   restaurants                       Tacos González     5.0
# 1  California   restaurants                         Subs n stuff     5.0
# 2  California   restaurants           Sabor a Oaxaca Restaurante     5.0
# 3  California   restaurants                     Taquizas Gracian     5.0
# 4  California   restaurants  Indulge! Crepes and Frozen Delights     5.0
#
#    Review Count Price Level                   Category  \
# 0             8         NaN                    Mexican
# 1             5         NaN         Breakfast & Brunch
# 2             5         NaN                    Mexican
# 3            15         NaN                    Mexican
# 4            13         NaN  Ice Cream & Frozen Yogurt
#
#                                         Address     City           Phone  \
# 0          114642 S 10th Ave, Hanford, CA 93230  Hanford  (559) 772-2439
# 1              605 E Main St, Visalia, CA 93292  Visalia  (559) 754-2871
# 2          131 E Yosemite Ave, Madera, CA 93638   Madera  (559) 285-0131
# 3            825 West Main St, Merced, CA 95340   Merced  (209) 382-5051
# 4  1127 N Willow Ave, Ste 105, Clovis, CA 93611   Clovis             NaN
#
#                                             Yelp URL
# 0  https://www.yelp.com/biz/tacos-gonz%C3%A1lez-h...
# 1  https://www.yelp.com/biz/subs-n-stuff-visalia?...
# 2  https://www.yelp.com/biz/sabor-a-oaxaca-restau...
# 3  https://www.yelp.com/biz/taquizas-gracian-no-t...
# 4  https://www.yelp.com/biz/indulge-crepes-and-fr...

# %% [markdown]
# ### **Step 3: Check Data Types & Missing Values**

# %%
# Check dataset info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          13200 non-null  object
#  1   Business Type  13200 non-null  object
#  2   Name           13200 non-null  object
#  3   Rating         13200 non-null  float64
#  4   Review Count   13200 non-null  int64
#  5   Price Level    3875 non-null   object
#  6   Category       13200 non-null  object
#  7   Address        13200 non-null  object
#  8   City           13200 non-null  object
#  9   Phone          12807 non-null  object
#  10  Yelp URL       13200 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 1.1+ MB

# %%
# Check for missing values

df.isnull().sum()
# Out:
# State               0
# Business Type       0
# Name                0
# Rating              0
# Review Count        0
# Price Level      9325
# Category            0
# Address             0
# City                0
# Phone             393
# Yelp URL            0
# dtype: int64

# %%
# Drop rows where essential fields are missing

df.dropna(subset=["State", "Business Type", "Name"], inplace=True)

# Fill missing numerical values

df["Rating"].fillna(df["Rating"].median(), inplace=True)
df["Review Count"].fillna(0, inplace=True)

# Fill missing categorical values

df["Price Level"].fillna("Unknown", inplace=True)
df["Category"].fillna("General", inplace=True)
df["Address"].fillna("Not Available", inplace=True)
df["City"].fillna("Not Available", inplace=True)
df["Phone"] = df["Phone"].str.replace(r"\D", "", regex=True) # Standardize phone numbers (keep only numbers)
df["Phone"].fillna("Not Provided", inplace=True)
# Out:
# C:\Users\Likhi\AppData\Local\Temp\ipykernel_47920\679440235.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Rating"].fillna(df["Rating"].median(), inplace=True)
# C:\Users\Likhi\AppData\Local\Temp\ipykernel_47920\679440235.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Review Count"].fillna(0, inplace=True)
# C:\Users\Likhi\AppData\Local\Temp\ipykernel_47920\679440235.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Price Level"].fillna("Unknown", inplace=True)
# C:\Users\Likhi\AppData\Local\Temp\ipykernel_47920\679440235.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Category"].fillna("General", inplace=True)
# C:\Users\Likhi\AppData\Local\Temp\ipykernel_47920\679440235.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Address"].fillna("Not Available", inplace=True)
# C:\Users\Likhi\AppData\Local\Temp\ipykernel_47920\679440235.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["City"].fillna("Not Available", inplace=True)
# C:\Users\Likhi\AppData\Local\Temp\ipykernel_47920\679440235.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Phone"].fillna("Not Provided", inplace=True)

# %%
# Convert numerical fields to correct types

df["Rating"] = df["Rating"].astype(float)
df["Review Count"] = df["Review Count"].astype(int)

# Convert price level: "$" → 1, "$$" → 2, "$$$" → 3, "$$$$" → 4, Unknown → 0

price_mapping = {"$": 1, "$$": 2, "$$$": 3, "$$$$": 4, "Unknown": 0}
df["Price Level"] = df["Price Level"].map(price_mapping)

# %% [markdown]
# ### **Step 4: Handling Duplicate Data**

# %%
# Remove Duplicates

df.drop_duplicates(inplace=True)

# %%
# Final Data Review

print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13197 entries, 0 to 13199
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          13197 non-null  object
#  1   Business Type  13197 non-null  object
#  2   Name           13197 non-null  object
#  3   Rating         13197 non-null  float64
#  4   Review Count   13197 non-null  int32
#  5   Price Level    13197 non-null  int64
#  6   Category       13197 non-null  object
#  7   Address        13197 non-null  object
#  8   City           13197 non-null  object
#  9   Phone          13197 non-null  object
#  10  Yelp URL       13197 non-null  object
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 1.2+ MB
# None
#         State Business Type                                 Name  Rating  \
# 0  California   restaurants                       Tacos González     5.0
# 1  California   restaurants                         Subs n stuff     5.0
# 2  California   restaurants           Sabor a Oaxaca Restaurante     5.0
# 3  California   restaurants                     Taquizas Gracian     5.0
# 4  California   restaurants  Indulge! Crepes and Frozen Delights     5.0
#
#    Review Count  Price Level                   Category  \
# 0             8            0                    Mexican
# 1             5            0         Breakfast & Brunch
# 2             5            0                    Mexican
# 3            15            0                    Mexican
# 4            13            0  Ice Cream & Frozen Yogurt
#
#                                         Address     City         Phone  \
# 0          114642 S 10th Ave, Hanford, CA 93230  Hanford    5597722439
# 1              605 E Main St, Visalia, CA 93292  Visalia    5597542871
# 2          131 E Yosemite Ave, Madera, CA 93638   Madera    5592850131
# 3            825 West Main St, Merced, CA 95340   Merced    2093825051
# 4  1127 N Willow Ave, Ste 105, Clovis, CA 93611   Clovis  Not Provided
#
#                                             Yelp URL
# 0  https://www.yelp.com/biz/tacos-gonz%C3%A1lez-h...
# 1  https://www.yelp.com/biz/subs-n-stuff-visalia?...
# 2  https://www.yelp.com/biz/sabor-a-oaxaca-restau...
# 3  https://www.yelp.com/biz/taquizas-gracian-no-t...
# 4  https://www.yelp.com/biz/indulge-crepes-and-fr...

# %% [markdown]
# ### **Step 5: Data Transformation**

# %%
# Rearranging df

df = df.reindex(columns= ['Business Type', 'Name', 'Rating', 'Review Count',
       'Price Level', 'Category', 'Address', 'City', 'State', 'Phone', 'Yelp URL'])

df
# Out:
#       Business Type                                 Name  Rating  \
# 0       restaurants                       Tacos González     5.0
# 1       restaurants                         Subs n stuff     5.0
# 2       restaurants           Sabor a Oaxaca Restaurante     5.0
# 3       restaurants                     Taquizas Gracian     5.0
# 4       restaurants  Indulge! Crepes and Frozen Delights     5.0
# ...             ...                                  ...     ...
# 13195        salons          Hair Adventure Beauty Salon     3.5
# 13196        salons                     My Mani Pedi Spa     3.5
# 13197        salons                           Salon Inez     4.0
# 13198        salons                  Yen Hair and Beauty     3.5
# 13199        salons                     City Nails & Spa     3.5
#
#        Review Count  Price Level                   Category  \
# 0                 8            0                    Mexican
# 1                 5            0         Breakfast & Brunch
# 2                 5            0                    Mexican
# 3                15            0                    Mexican
# 4                13            0  Ice Cream & Frozen Yogurt
# ...             ...          ...                        ...
# 13195            91            3                Hair Salons
# 13196            89            2                Nail Salons
# 13197             3            0                Hair Salons
# 13198            25            1                Hair Salons
# 13199           177            2                Nail Salons
#
#                                             Address     City          State  \
# 0              114642 S 10th Ave, Hanford, CA 93230  Hanford     California
# 1                  605 E Main St, Visalia, CA 93292  Visalia     California
# 2              131 E Yosemite Ave, Madera, CA 93638   Madera     California
# 3                825 West Main St, Merced, CA 95340   Merced     California
# 4      1127 N Willow Ave, Ste 105, Clovis, CA 93611   Clovis     California
# ...                                             ...      ...            ...
# 13195              32 Boylston St, Boston, MA 02111   Boston  Massachusetts
# 13196             546A Tremont St, Boston, MA 02116   Boston  Massachusetts
# 13197              114 Newbury St, Boston, MA 02116   Boston  Massachusetts
# 13198                              Boston, MA 02111   Boston  Massachusetts
# 13199          1260 Washington St, Boston, MA 02118   Boston  Massachusetts
#
#               Phone                                           Yelp URL
# 0        5597722439  https://www.yelp.com/biz/tacos-gonz%C3%A1lez-h...
# 1        5597542871  https://www.yelp.com/biz/subs-n-stuff-visalia?...
# 2        5592850131  https://www.yelp.com/biz/sabor-a-oaxaca-restau...
# 3        2093825051  https://www.yelp.com/biz/taquizas-gracian-no-t...
# 4      Not Provided  https://www.yelp.com/biz/indulge-crepes-and-fr...
# ...             ...                                                ...
# 13195    6173389338  https://www.yelp.com/biz/hair-adventure-beauty...
# 13196    6174825550  https://www.yelp.com/biz/my-mani-pedi-spa-bost...
# 13197    6172062066  https://www.yelp.com/biz/salon-inez-boston?adj...
# 13198    6173383888  https://www.yelp.com/biz/yen-hair-and-beauty-b...
# 13199    6179888189  https://www.yelp.com/biz/city-nails-and-spa-bo...
#
# [13197 rows x 11 columns]

# %%
# Renaming the headers to match the MySQL table

df.rename(columns={'Business Type': 'business_type'}, inplace=True)
df.rename(columns={'Review Count': 'review_count'}, inplace=True)
df.rename(columns={'Price Level': 'price_level'}, inplace=True)
df.rename(columns={'Yelp URL': 'yelp_url'}, inplace=True)
df.rename(columns={'Name': 'name'}, inplace=True)
df.rename(columns={'Rating': 'rating'}, inplace=True)
df.rename(columns={'Category': 'category'}, inplace=True)
df.rename(columns={'Address': 'address'}, inplace=True)
df.rename(columns={'City': 'city'}, inplace=True)
df.rename(columns={'State': 'state'}, inplace=True)
df.rename(columns={'Phone': 'phone'}, inplace=True)

df
# Out:
#       business_type                                 name  rating  \
# 0       restaurants                       Tacos González     5.0
# 1       restaurants                         Subs n stuff     5.0
# 2       restaurants           Sabor a Oaxaca Restaurante     5.0
# 3       restaurants                     Taquizas Gracian     5.0
# 4       restaurants  Indulge! Crepes and Frozen Delights     5.0
# ...             ...                                  ...     ...
# 13195        salons          Hair Adventure Beauty Salon     3.5
# 13196        salons                     My Mani Pedi Spa     3.5
# 13197        salons                           Salon Inez     4.0
# 13198        salons                  Yen Hair and Beauty     3.5
# 13199        salons                     City Nails & Spa     3.5
#
#        review_count  price_level                   category  \
# 0                 8            0                    Mexican
# 1                 5            0         Breakfast & Brunch
# 2                 5            0                    Mexican
# 3                15            0                    Mexican
# 4                13            0  Ice Cream & Frozen Yogurt
# ...             ...          ...                        ...
# 13195            91            3                Hair Salons
# 13196            89            2                Nail Salons
# 13197             3            0                Hair Salons
# 13198            25            1                Hair Salons
# 13199           177            2                Nail Salons
#
#                                             address     city          state  \
# 0              114642 S 10th Ave, Hanford, CA 93230  Hanford     California
# 1                  605 E Main St, Visalia, CA 93292  Visalia     California
# 2              131 E Yosemite Ave, Madera, CA 93638   Madera     California
# 3                825 West Main St, Merced, CA 95340   Merced     California
# 4      1127 N Willow Ave, Ste 105, Clovis, CA 93611   Clovis     California
# ...                                             ...      ...            ...
# 13195              32 Boylston St, Boston, MA 02111   Boston  Massachusetts
# 13196             546A Tremont St, Boston, MA 02116   Boston  Massachusetts
# 13197              114 Newbury St, Boston, MA 02116   Boston  Massachusetts
# 13198                              Boston, MA 02111   Boston  Massachusetts
# 13199          1260 Washington St, Boston, MA 02118   Boston  Massachusetts
#
#               phone                                           yelp_url
# 0        5597722439  https://www.yelp.com/biz/tacos-gonz%C3%A1lez-h...
# 1        5597542871  https://www.yelp.com/biz/subs-n-stuff-visalia?...
# 2        5592850131  https://www.yelp.com/biz/sabor-a-oaxaca-restau...
# 3        2093825051  https://www.yelp.com/biz/taquizas-gracian-no-t...
# 4      Not Provided  https://www.yelp.com/biz/indulge-crepes-and-fr...
# ...             ...                                                ...
# 13195    6173389338  https://www.yelp.com/biz/hair-adventure-beauty...
# 13196    6174825550  https://www.yelp.com/biz/my-mani-pedi-spa-bost...
# 13197    6172062066  https://www.yelp.com/biz/salon-inez-boston?adj...
# 13198    6173383888  https://www.yelp.com/biz/yen-hair-and-beauty-b...
# 13199    6179888189  https://www.yelp.com/biz/city-nails-and-spa-bo...
#
# [13197 rows x 11 columns]

# %%
# Define new price level mapping
price_mapping = {0: 15, 1: 20, 2: 50, 3: 100, 4: 250}

# Apply the mapping
df["Mapped_Price_Level"] = df["price_level"].map(price_mapping)

# Save updated dataset
df.to_csv("data/updated_cleaned_yelp_data.csv", index=False)

# %% [markdown]
# ### **Step 6: Initializing Connection to MySQL**

# %%
# Connect to MySQL

password_encoded = quote_plus("Likhith@704")

engine_mysql = create_engine(f"mysql+pymysql://root:{password_encoded}@localhost:3306/yelp")

try:
    engine_mysql
    print("Connection Successfull to MySql")
except:
    print("Unable to connect to MySql")
# Out:
# Connection Successfull to MySql

# %% [markdown]
# ### **Step 7: Export Cleaned Data to MySQL**

# %%
# Insert into MySQL

try:
    df.to_sql(name="yelp_businesses", con=engine_mysql, if_exists="append", index=False)
    print("✅ Data successfully inserted into MySQL!")
except Exception as e:
    print(f"⚠️ Error inserting data: {e}")
# Out:
# ✅ Data successfully inserted into MySQL!
